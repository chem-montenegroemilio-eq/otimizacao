# %%
lista_teste1 = ['a', 's', 'a_3']
lista_teste2 = ['b', 's', '_3']

lista_resposta = [True  for item in lista_teste1 if 'a' in item]
print(lista_resposta)
# Out:
#   Cell In[10], line 6
#     lista_resposta = [True for item in lista_teste1 if 'a' in item else print('nao existe')]
#                                                                    ^
# SyntaxError: invalid syntax
